# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
fig = plt.figure(figsize=(12,18))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
temp=0
temp_1=0
temp_2=0
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[temp]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[temp]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off')
    ax.set_title(stem_cats[temp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp+=1
    if sp+1 == 1:
        ax.text(2002,85,'Women')
        ax.text(2006,16,'Men')
    if sp+1 == 16:
        ax.text(2002,10,'Women')
        ax.text(2006,88,'Men')
    
for sp in range(0,15,3):
    ax = fig.add_subplot(6,3,sp+2)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[temp_1]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[temp_1]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off')
    ax.set_title(lib_arts_cats[temp_1])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp_1+=1
    if sp+2 == 2:
        ax.text(2002,80,'Women')
        ax.text(2006,20,'Men')
    
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[temp_2]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[temp_2]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off')
    ax.set_title(other_cats[temp_2])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp_2+=1
    if sp+3 == 3:
        ax.text(2002,90,'Women')
        ax.text(2006,8,'Men')
    if sp+3 == 18:
        ax.text(2002,35,'Women')
        ax.text(2006,62,'Men')

# %%
#same code as above except a couple of lines added to disable all labels except for the bottom most chart
fig = plt.figure(figsize=(12,18))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
temp=0
temp_1=0
temp_2=0
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[temp]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[temp]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(stem_cats[temp])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp+=1
    if sp+1 == 1:
        ax.text(2002,85,'Women')
        ax.text(2006,16,'Men')
    if sp+1 == 16:
        ax.text(2002,10,'Women')
        ax.text(2006,88,'Men')
        ax.tick_params(labelbottom='on')
    
for sp in range(0,15,3):
    ax = fig.add_subplot(6,3,sp+2)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[temp_1]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[temp_1]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(lib_arts_cats[temp_1])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp_1+=1
    if sp+2 == 2:
        ax.text(2002,80,'Women')
        ax.text(2006,20,'Men')
    if sp+2 == 14:
        ax.tick_params(labelbottom='on')
    
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[temp_2]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[temp_2]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(other_cats[temp_2])
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    temp_2+=1
    if sp+3 == 3:
        ax.text(2002,90,'Women')
        ax.text(2006,8,'Men')
    if sp+3 == 18:
        ax.text(2002,35,'Women')
        ax.text(2006,62,'Men')
        ax.tick_params(labelbottom='on')

# %%
#same code as above except line added to set the y-axis labels
fig = plt.figure(figsize=(12,18))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
temp=0
temp_1=0
temp_2=0
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[temp]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[temp]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(stem_cats[temp])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    temp+=1
    if sp+1 == 1:
        ax.text(2002,85,'Women')
        ax.text(2006,16,'Men')
    if sp+1 == 16:
        ax.text(2002,10,'Women')
        ax.text(2006,88,'Men')
        ax.tick_params(labelbottom='on')
    
for sp in range(0,15,3):
    ax = fig.add_subplot(6,3,sp+2)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[temp_1]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[temp_1]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(lib_arts_cats[temp_1])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    temp_1+=1
    if sp+2 == 2:
        ax.text(2002,80,'Women')
        ax.text(2006,20,'Men')
    if sp+2 == 14:
        ax.tick_params(labelbottom='on')
    
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[temp_2]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[temp_2]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(other_cats[temp_2])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    temp_2+=1
    if sp+3 == 3:
        ax.text(2002,90,'Women')
        ax.text(2006,8,'Men')
    if sp+3 == 18:
        ax.text(2002,35,'Women')
        ax.text(2006,62,'Men')
        ax.tick_params(labelbottom='on')

# %%
#same code but with lines added for a horizontal line at y=50 and saving figure to gender_degrees
fig = plt.figure(figsize=(12,18))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
temp=0
temp_1=0
temp_2=0
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[temp]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[temp]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(stem_cats[temp])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    temp+=1
    if sp+1 == 1:
        ax.text(2002,85,'Women')
        ax.text(2006,16,'Men')
    if sp+1 == 16:
        ax.text(2002,10,'Women')
        ax.text(2006,88,'Men')
        ax.tick_params(labelbottom='on')
    
for sp in range(0,15,3):
    ax = fig.add_subplot(6,3,sp+2)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[temp_1]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[temp_1]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(lib_arts_cats[temp_1])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    temp_1+=1
    if sp+2 == 2:
        ax.text(2002,80,'Women')
        ax.text(2006,20,'Men')
    if sp+2 == 14:
        ax.tick_params(labelbottom='on')
    
for sp in range(0,18,3):
    ax = fig.add_subplot(6,3,sp+3)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[temp_2]],c=cb_dark_blue)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[temp_2]],c=cb_orange)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.tick_params(left='off',right='off',top='off',bottom='off',labelbottom='off')
    ax.set_title(other_cats[temp_2])
    ax.set_xlim(1968, 2011)
    ax.set_yticks([0,100])
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.3)
    temp_2+=1
    if sp+3 == 3:
        ax.text(2002,90,'Women')
        ax.text(2006,8,'Men')
    if sp+3 == 18:
        ax.text(2002,35,'Women')
        ax.text(2006,62,'Men')
        ax.tick_params(labelbottom='on')
plt.savefig('gender_degrees.png')
plt.show()

# %%
plt.get_backend() #to check the backend being used
# Out:
# 'module://ipykernel.pylab.backend_inline'
